# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib as plt

# %%
np.random.randint(1000)
# Out:
# 8

# %%
df = pd.DataFrame(np.random.randn(1000), columns = ['Data']  )

# %%
df
# Out:
#          Data
# 0    0.810879
# 1   -1.636595
# 2    2.061878
# 3   -0.251179
# 4   -1.537411
# ..        ...
# 995 -0.640173
# 996 -2.468831
# 997  1.653203
# 998 -0.791071
# 999  0.622817
#
# [1000 rows x 1 columns]

# %%
df.plot(figsize = (20,10))
# Out:
# <Axes: >

# %%
df = pd.read_csv('https://gist.githubusercontent.com/curran/a08a1080b88344b0c8a7/raw/0e7a9b0a5d22642a06d3d5b9bcbad9890c8ee534/iris.csv')

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df.plot(figsize = (20,10))
# Out:
# <Axes: >

# %%
df.head().plot(kind = 'bar' , figsize = (20,10))
# Out:
# <Axes: >

# %%
df.iloc[5:11].plot(kind = 'barh' , figsize = (20,10))
# Out:
# <Axes: >

# %%
df.iloc[[5]]
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 5           5.4          3.9           1.7          0.4  setosa

# %%
 df.plot(kind = 'hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df['sepal_length'].plot()
# Out:
# <Axes: >

# %%
df['sepal_length'].plot(kind = 'hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['sepal_length']
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: sepal_length, Length: 150, dtype: float64

# %%
df['sepal_length'].plot(kind = 'hist' , orientation = 'horizontal')
# Out:
# <Axes: xlabel='Frequency'>

# %%
df.hist()
# Out:
# array([[<Axes: title={'center': 'sepal_length'}>,
#         <Axes: title={'center': 'sepal_width'}>],
#        [<Axes: title={'center': 'petal_length'}>,
#         <Axes: title={'center': 'petal_width'}>]], dtype=object)

# %%
df.hist(figsize = (20,10))
# Out:
# array([[<Axes: title={'center': 'sepal_length'}>,
#         <Axes: title={'center': 'sepal_width'}>],
#        [<Axes: title={'center': 'petal_length'}>,
#         <Axes: title={'center': 'petal_width'}>]], dtype=object)

# %%
df.hist(figsize = (20,10) , color = 'red')
# Out:
# array([[<Axes: title={'center': 'sepal_length'}>,
#         <Axes: title={'center': 'sepal_width'}>],
#        [<Axes: title={'center': 'petal_length'}>,
#         <Axes: title={'center': 'petal_width'}>]], dtype=object)

# %%
df.hist(figsize = (20,10) , color = 'g')
# Out:
# array([[<Axes: title={'center': 'sepal_length'}>,
#         <Axes: title={'center': 'sepal_width'}>],
#        [<Axes: title={'center': 'petal_length'}>,
#         <Axes: title={'center': 'petal_width'}>]], dtype=object)

# %%
df.hist(figsize = (20,10) ,color = 'g' , alpha = .5)
# Out:
# array([[<Axes: title={'center': 'sepal_length'}>,
#         <Axes: title={'center': 'sepal_width'}>],
#        [<Axes: title={'center': 'petal_length'}>,
#         <Axes: title={'center': 'petal_width'}>]], dtype=object)

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df.plot(kind = 'box')
# Out:
# <Axes: >

# %%
df.plot(kind = 'box' , figsize = (20,10))
# Out:
# <Axes: >

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df.plot(kind = 'box' , figsize = (20,10) , color = 'r')
# Out:
# <Axes: >

# %%
df.plot(kind = 'box' , figsize = (20,10) , color = {'boxes' : 'g' , 'whiskers' : 'r'})
# Out:
# <Axes: >

# %%
df.plot(kind = 'box' , figsize = (20,10) , color = {'boxes' : 'g' , 'whiskers' : 'r'} , vert = False)
# Out:
# <Axes: >

# %%
df.plot(kind = 'area' , figsize = (20,10))
# Out:
# <Axes: >

# %%
df.plot(kind = 'area' , figsize = (20,10) , alpha = 0.5)
# Out:
# <Axes: >

# %%
df.plot(kind = 'area' , figsize = (20,10) , alpha = 0.5 , stacked = False)
# Out:
# <Axes: >

# %%
df.plot(figsize = (20,10))
# Out:
# <Axes: >

# %%
df.plot.scatter(x = 'sepal_length' , y = 'petal_width')
# Out:
# <Axes: xlabel='sepal_length', ylabel='petal_width'>

# %%
df.plot.scatter(x = 'sepal_length' , y = 'petal_length')
# Out:
# <Axes: xlabel='sepal_length', ylabel='petal_length'>

# %%
df.plot.scatter(x = 'sepal_length' , y = 'petal_length' , c = 'sepal_width')
# Out:
# <Axes: xlabel='sepal_length', ylabel='petal_length'>

# %%
df.plot.scatter(x = 'sepal_length' , y = 'petal_length' , s = 600)
# Out:
# <Axes: xlabel='sepal_length', ylabel='petal_length'>

# %%
df.plot.scatter(x = 'sepal_length' , y = 'petal_length' , s = df['petal_width']*500 , c = 'gray')
# Out:
# <Axes: xlabel='sepal_length', ylabel='petal_length'>

# %%
df.plot.hexbin(x = 'sepal_length' , y = 'petal_length' ,gridsize = 10)
# Out:
# <Axes: xlabel='sepal_length', ylabel='petal_length'>

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df.iloc[0]
# Out:
# sepal_length       5.1
# sepal_width        3.5
# petal_length       1.4
# petal_width        0.2
# species         setosa
# Name: 0, dtype: object

# %%
df.iloc[[0]]
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa

# %%
df1 = df.drop(columns = 'species').iloc[0]

# %%
df1.plot(kind = 'pie')
# Out:
# <Axes: ylabel='0'>

# %%
df1
# Out:
# sepal_length    5.1
# sepal_width     3.5
# petal_length    1.4
# petal_width     0.2
# Name: 0, dtype: float64

# %%
pip install plotly

# %%
import cufflinks as cf

# %%
pip install cufflinks

# %%
import cufflinks as cf

# %%
df.iplot()

# %%
pip install chart_studio

# %%
df.iplot()
